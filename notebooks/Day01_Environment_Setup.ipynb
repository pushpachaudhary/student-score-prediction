# %% [markdown]
# # Day 1 -  Environment Setup Tasks
# -Install Python, VS Code, Jupyter Notebook and Git.
# -Learn the basics of Artificial Intelligence, Machine Learning and Data Science.
# -Create a GitHub repository and run first Python program.

# %%
print("Hello , It's DAy 1 of my machine learning journey.")
# Out:
# Hello , It's DAy 1 of my machine learning journey.
